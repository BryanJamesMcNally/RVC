# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel ('BudgetReport_2.xlsx')

df.drop(df.tail(1).index,inplace=True)
df
# Out:
#                                             Code  Estimates  Revised Costs  \
# 0                             1000S Design - sub        0.0           0.00
# 1                          1005S Architect - sub        0.0           0.00
# 2                        1007S Engineering - sub        0.0           0.00
# 3              1008L Project management - labor     16100.0       16100.00
# 4                   1010S Building permits - sub        0.0           0.00
# 5                            1120S Surveys - sub     1500.0        1500.00
# 6             1220M Fill dirt and material - mat     1000.0        1000.00
# 7                       1300L Demolition - labor      500.0         500.00
# 8                           1301S Dumpster - sub     1350.0        1350.00
# 9                         1302S Port-a-Jon - sub     1650.0        1650.00
# 10           2000S Excavation and backfill - sub     3000.0        3000.00
# ...

# %%
df.describe(include='all')
# Out:
#                       Code     Estimates  Revised Costs     Bills/POs  \
# count                   50     50.000000      50.000000     50.000000
# unique                  50           NaN            NaN           NaN
# top     1000S Design - sub           NaN            NaN           NaN
# freq                     1           NaN            NaN           NaN
# mean                   NaN   5240.420000    5487.195000   2207.918400
# std                    NaN   9676.466893    9210.481819   6740.721198
# min                    NaN      0.000000       0.000000      0.000000
# 25%                    NaN    395.000000     525.000000      0.000000
# 50%                    NaN   1275.000000    1500.000000      0.000000
# 75%                    NaN   7225.000000    7500.000000    774.107500
# max                    NaN  55000.000000   45000.000000  36760.000000
#
#         Time Clock Labor  Builder Variance  Total Bill/PO Cost  \
# ...

# %%
df.dtypes
# Out:
# Code                            object
# Estimates                      float64
# Revised Costs                  float64
# Bills/POs                      float64
# Time Clock Labor               float64
# Builder Variance                 int64
# Total Bill/PO Cost             float64
# Customer Variance                int64
# Total Costs                    float64
# Paid                           float64
# Outstanding                      int64
# Estimates vs. Revised Costs    float64
# dtype: object

# %%
df.plot(x="Code", y=["Estimates", "Revised Costs"], kind="bar",figsize=(20,8))
plt.show()
